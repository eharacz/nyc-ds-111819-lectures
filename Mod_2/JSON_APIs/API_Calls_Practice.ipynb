# %% [markdown]
# ## Starting Off
#
# Think of one lingering quetion you have about SQL and sedd it to our slack class channel.

# %% [markdown]
# # Using APIs and JSON Data

# %% [markdown]
# ## Objectives
# You will be able to:
# * Make an API call to Yelp

# %% [markdown]
# ## Agenda
#
# * Build up an API Call
# * Look at the results

# %%
import requests
import json

# %% [markdown]
# For more information about the request package you can use the following resources:
#
# **Tutorial:** https://realpython.com/python-requests/
#
# **Package Documentation:** https://requests.readthedocs.io/en/master/

# %% [markdown]
# ![](quota.png)

# %% [markdown]
# Let's do a serach of businesses on the Yelp API.

# %%
# set theurl and endpoint we want to hit
url = 'https://api.yelp.com/v3/businesses/search'

# %% [markdown]
# Now that you have an API key, let's enter set that information here so that we can do our searches. Once you have the `api_key` variable, place int in our header.

# %%
client_id = 'SrP-vVinyIiYU2-NOuqnOA'
api_key = 'CaJ2qY7XSMjW7nhV9IK8KiEYI6Yj3kPAXR6Jdgstzo-YOFuAfT3AbrRF6UID6P9ia75sS8dzlih1HNcZEK1EHzu8Dp-gOnC3eVdyNpHKt4iJIUIOC7ovxCM68jrpXXYx'

# %%
#client_id = 'bVX1Jsfp4dkIOqw5HOVplg' #Your client ID goes here (as a string)
#api_key = 'RTzp-q-TgkJW_NFQogubFvZNRDziXyoR38VbtZMWibDI-FlvB25OE7GmafFEqhTL8_Bk2HlcX24-hRWLMP7Nc6WHO_VXMXldpPBjP0LoPv5EFFELMSI2oll8njhbXHYx' #Your api key goes here (as a string)

# %%
headers = {
        'Authorization': 'Bearer {}'.format(api_key),
    }

# %% [markdown]
# We now need to determine our parameters we want to pass.
#
# You must give a specific search term, location and one other paramter to limit your search.
#
# Remember you can search the API documenation to find another parameter to limit your search.
# https://www.yelp.com/developers/documentation/v3/get_started

# %%
# what type of business do you want to search
term = 'pizza'

#where do you want to perform this search
location = 'East Village'

# what is your other parameter you want to search against
radius = 10000

# %%
url_params = {
                'term': term.replace(' ', '+'),
                'location': location.replace(' ', '+'),
                "radius" : radius
            }

# %% [markdown]
# Now that we have all of the parts necessary for an API call, let's put them together.

# %%
response = requests.get(url, headers=headers, params=url_params)

# %% [markdown]
# ## The Response
#
# The response of a GET request often has some valuable information, known as a payload, in the message body. Using the attributes and methods of Response, you can view the payload in a variety of different formats.
#
# To see the response’s content in bytes, you use `.content`
#
# You will often want to convert them into a string using a character encoding such as UTF-8. Response will do that for you when you access `.text`
#
# The response is actually serialized JSON content. To get a dictionary, you could take the str you retrieved from `.text` and deserialize it using `json.loads()`. However, a simpler way to accomplish this task is to use `.json()`:

# %%
json.loads(response.text)
# Out:
# {'businesses': [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#    'alias': 'prince-street-pizza-new-york-2',
#    'name': 'Prince Street Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 3271,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7229087705545,
#     'longitude': -73.9944863319397},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '27 Prince St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Prince St', 'New York, NY 10012']},
#    'phone': '+12129664100',
#    'display_phone': '(212) 966-4100',
#    'distance': 1113.4297052662043},
#   {'id': 'WIhm0W9197f_rRtDziq5qQ',
#    'alias': 'lombardis-pizza-new-york-4',
#    'name': "Lombardi's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_hobp1KpYDPOHNoCKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 6018,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7215934960083,
#     'longitude': -73.9955956044561},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '32 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Spring St', 'New York, NY 10012']},
#    'phone': '+12129417994',
#    'display_phone': '(212) 941-7994',
#    'distance': 1258.1061902840042},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-pizza-brooklyn-5',
#    'name': "Juliana's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 2123,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7026153030093,
#     'longitude': -73.9934159993549},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 2827.1903279864737},
#   {'id': 'EMKsuz1fQIGqmWPp3ZEDmA',
#    'alias': 'vitos-slices-and-ices-new-york-2',
#    'name': "Vito's Slices and Ices",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TfC8XKeabuGpecol-zhFsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vitos-slices-and-ices-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 40,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'shavedice', 'title': 'Shaved Ice'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7545, 'longitude': -73.99528},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '464 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['464 9th Ave', 'New York, NY 10018']},
#    'phone': '+12122731186',
#    'display_phone': '(212) 273-1186',
#    'distance': 3289.319693332509},
#   {'id': 'nUpA3sY5b6dynC7aj0eV6A',
#    'alias': 'rizzos-fine-pizza-new-york-4',
#    'name': "Rizzo's Fine Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dnLj-NVZx4TUp608hDVBvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rizzos-fine-pizza-new-york-4?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 719,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720852, 'longitude': -73.984456},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '17 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Clinton St', 'New York, NY 10002']},
#    'phone': '+16464541262',
#    'display_phone': '(646) 454-1262',
#    'distance': 664.3833144456129},
#   {'id': 'v1DHGRNCH9247WLYoaoA9A',
#    'alias': 'l-industrie-pizzeria-brooklyn',
#    'name': "L'industrie Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SRL_RztRRUijgQwt67daGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 495,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '254 S 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#    'phone': '+17185990002',
#    'display_phone': '(718) 599-0002',
#    'distance': 2641.933271386537},
#   {'id': '2ZALEmIVm_t4tYLGXxd2dw',
#    'alias': 'lions-and-tigers-and-squares-detroit-pizza-new-york-2',
#    'name': 'Lions & Tigers & Squares Detroit Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/v3U5mEG74wzyOKHNaBhcJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lions-and-tigers-and-squares-detroit-pizza-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 31,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72981, 'longitude': -73.98658},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '160 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 2nd Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 508.9226680521954},
#   {'id': '-CCfu19Uuy_kD2t4ZwsQfA',
#    'alias': 'village-square-pizza-new-york-3',
#    'name': 'Village Square Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rc1se5XkYcc6ABo8g7u4Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/village-square-pizza-new-york-3?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 102,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72748, 'longitude': -73.98268},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '147 Ave A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 Ave A', 'New York, NY 10009']},
#    'phone': '+19176757709',
#    'display_phone': '(917) 675-7709',
#    'distance': 115.03507796790193},
#   {'id': 'uc5qQMzs96rzjK27epDCug',
#    'alias': 'joes-pizza-new-york-4',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG9HFmEGaTSBMcUBhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 2461,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730655, 'longitude': -74.002189},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '7 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Carmine St', 'New York, NY 10014']},
#    'phone': '+12123661182',
#    'display_phone': '(212) 366-1182',
#    'distance': 1743.7585301414076},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 2111,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72275, 'longitude': -73.99622},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1254.8987502464195},
#   {'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#    'alias': 'joes-pizza-new-york-7',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9E2Um0ddicKyoWS-RGIXyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 843,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73331, 'longitude': -73.98763},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '150 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 E 14th St', 'New York, NY 10003']},
#    'phone': '+12123889474',
#    'display_phone': '(212) 388-9474',
#    'distance': 865.5899869147826},
#   {'id': 'Ajvcvk6tvlKbRF8Zkf0M5Q',
#    'alias': 'marinara-pizza-new-york-8',
#    'name': 'Marinara Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/14ta7LbwwXc7Jdh2LRuTBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marinara-pizza-new-york-8?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 19,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74241, 'longitude': -73.98452},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '379 Park Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['379 Park Ave S', 'New York, NY 10016']},
#    'phone': '+16466495282',
#    'display_phone': '(646) 649-5282',
#    'distance': 1770.736647438582},
#   {'id': 'eVk4F9ixl89zyUHJ1G2Aiw',
#    'alias': 'luzzos-la-pizza-napoletana-new-york-10',
#    'name': 'Luzzos La Pizza Napoletana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/siQq0MnFSCXmAd8rg28EwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luzzos-la-pizza-napoletana-new-york-10?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 1032,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730616, 'longitude': -73.9834846},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '211 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 1st Ave', 'New York, NY 10003']},
#    'phone': '+12124737447',
#    'display_phone': '(212) 473-7447',
#    'distance': 462.36038428059834},
#   {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#    'alias': 'johns-of-bleecker-street-new-york-2',
#    'name': "John's of Bleecker Street",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ey_5ReYpouWm4SlY2DsaVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 1946,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '278 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122431680',
#    'display_phone': '(212) 243-1680',
#    'distance': 1876.8363324785919},
#   {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#    'alias': 'bleecker-street-pizza-new-york',
#    'name': 'Bleecker Street Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP43S_a6s-zXD38NUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 2276,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7320627016512,
#     'longitude': -74.0036552270137},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '69 7th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12129244466',
#    'display_phone': '(212) 924-4466',
#    'distance': 1891.7926117225477},
#   {'id': 'MeQU-nGaQvX12VXYOyzavQ',
#    'alias': 'gruppo-new-york-4',
#    'name': 'Gruppo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mCZI4W3FgjwMS-G054lxZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gruppo-new-york-4?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 249,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72474, 'longitude': -73.98161},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '98 Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['98 Ave B', 'New York, NY 10009']},
#    'phone': '+12129952100',
#    'display_phone': '(212) 995-2100',
#    'distance': 209.4694403367121},
#   {'id': 'orvnuNWLuoE3-iEx4Aj8eA',
#    'alias': 'bakers-pizza-new-york',
#    'name': "Baker's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3TbUAZcHe7PQ278pONEU0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bakers-pizza-new-york?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 199,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7294399, 'longitude': -73.98125},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '201 Avenue A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Avenue A', 'New York, NY 10009']},
#    'phone': '+12127777477',
#    'display_phone': '(212) 777-7477',
#    'distance': 330.347070163572},
#   {'id': 'vfYhEpp0x-DrNjC6GSJjPQ',
#    'alias': 'artichoke-basilles-pizza-new-york-2',
#    'name': "Artichoke Basille's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/53JHO_-CRJ_e43JJIuN_Og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 3910,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7321124557704,
#     'longitude': -73.9839056828882},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '321 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 E 14th St', 'New York, NY 10003']},
#    'phone': '+12122282004',
#    'display_phone': '(212) 228-2004',
#    'distance': 632.4507704855928},
#   {'id': 'BgGz5IdV53bGb4o7opR5zg',
#    'alias': 'arturos-new-york',
#    'name': "Arturo's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Eh-8a3MUYlpatlpHs3mHJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arturos-new-york?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 665,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7273563342024,
#     'longitude': -74.0004944801331},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '106 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 W Houston St', 'New York, NY 10012']},
#    'phone': '+12126773820',
#    'display_phone': '(212) 677-3820',
#    'distance': 1544.8068092117087},
#   {'id': 'zmIrZgWhRdyRMrnEs9D3KA',
#    'alias': 'la-margarita-pizzeria-new-york',
#    'name': 'La Margarita Pizzeria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7NH6z9iOZETlq8AKFwkcyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-margarita-pizzeria-new-york?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 284,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7215392420787,
#     'longitude': -73.9876275438289},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '168 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19172614983',
#    'display_phone': '(917) 261-4983',
#    'distance': 723.4903673179167}],
#  'total': 5200,
#  'region': {'center': {'longitude': -73.98219108581543,
#    'latitude': 40.726575080877375}}}

# %%
#below works the same as the above

# %%
response.json()
# Out:
# {'businesses': [{'id': 'zj8Lq1T8KIC5zwFief15jg',
#    'alias': 'prince-street-pizza-new-york-2',
#    'name': 'Prince Street Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 3271,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7229087705545,
#     'longitude': -73.9944863319397},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '27 Prince St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['27 Prince St', 'New York, NY 10012']},
#    'phone': '+12129664100',
#    'display_phone': '(212) 966-4100',
#    'distance': 1113.4297052662043},
#   {'id': 'WIhm0W9197f_rRtDziq5qQ',
#    'alias': 'lombardis-pizza-new-york-4',
#    'name': "Lombardi's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/UZ6V_hobp1KpYDPOHNoCKw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lombardis-pizza-new-york-4?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 6018,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7215934960083,
#     'longitude': -73.9955956044561},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '32 Spring St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['32 Spring St', 'New York, NY 10012']},
#    'phone': '+12129417994',
#    'display_phone': '(212) 941-7994',
#    'distance': 1258.1061902840042},
#   {'id': 'ysqgdbSrezXgVwER2kQWKA',
#    'alias': 'julianas-pizza-brooklyn-5',
#    'name': "Juliana's Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7JtwTxhWHf3YS70Ss_CfxA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/julianas-pizza-brooklyn-5?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 2123,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7026153030093,
#     'longitude': -73.9934159993549},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '19 Old Fulton St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11201',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['19 Old Fulton St', 'Brooklyn, NY 11201']},
#    'phone': '+17185966700',
#    'display_phone': '(718) 596-6700',
#    'distance': 2827.1903279864737},
#   {'id': 'EMKsuz1fQIGqmWPp3ZEDmA',
#    'alias': 'vitos-slices-and-ices-new-york-2',
#    'name': "Vito's Slices and Ices",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TfC8XKeabuGpecol-zhFsQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/vitos-slices-and-ices-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 40,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'shavedice', 'title': 'Shaved Ice'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.7545, 'longitude': -73.99528},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '464 9th Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10018',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['464 9th Ave', 'New York, NY 10018']},
#    'phone': '+12122731186',
#    'display_phone': '(212) 273-1186',
#    'distance': 3289.319693332509},
#   {'id': 'nUpA3sY5b6dynC7aj0eV6A',
#    'alias': 'rizzos-fine-pizza-new-york-4',
#    'name': "Rizzo's Fine Pizza",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/dnLj-NVZx4TUp608hDVBvw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rizzos-fine-pizza-new-york-4?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 719,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.720852, 'longitude': -73.984456},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '17 Clinton St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['17 Clinton St', 'New York, NY 10002']},
#    'phone': '+16464541262',
#    'display_phone': '(646) 454-1262',
#    'distance': 664.3833144456129},
#   {'id': 'v1DHGRNCH9247WLYoaoA9A',
#    'alias': 'l-industrie-pizzeria-brooklyn',
#    'name': "L'industrie Pizzeria",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/SRL_RztRRUijgQwt67daGw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/l-industrie-pizzeria-brooklyn?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 495,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 40.71162, 'longitude': -73.95783},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '254 S 2nd St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'zip_code': '11211',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['254 S 2nd St', 'Brooklyn, NY 11211']},
#    'phone': '+17185990002',
#    'display_phone': '(718) 599-0002',
#    'distance': 2641.933271386537},
#   {'id': '2ZALEmIVm_t4tYLGXxd2dw',
#    'alias': 'lions-and-tigers-and-squares-detroit-pizza-new-york-2',
#    'name': 'Lions & Tigers & Squares Detroit Pizza',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/v3U5mEG74wzyOKHNaBhcJA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/lions-and-tigers-and-squares-detroit-pizza-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 31,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72981, 'longitude': -73.98658},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '160 2nd Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['160 2nd Ave', 'New York, NY 10003']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 508.9226680521954},
#   {'id': '-CCfu19Uuy_kD2t4ZwsQfA',
#    'alias': 'village-square-pizza-new-york-3',
#    'name': 'Village Square Pizza',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/rc1se5XkYcc6ABo8g7u4Zw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/village-square-pizza-new-york-3?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 102,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72748, 'longitude': -73.98268},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '147 Ave A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['147 Ave A', 'New York, NY 10009']},
#    'phone': '+19176757709',
#    'display_phone': '(917) 675-7709',
#    'distance': 115.03507796790193},
#   {'id': 'uc5qQMzs96rzjK27epDCug',
#    'alias': 'joes-pizza-new-york-4',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/1TvTRG9HFmEGaTSBMcUBhA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-4?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 2461,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730655, 'longitude': -74.002189},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '7 Carmine St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['7 Carmine St', 'New York, NY 10014']},
#    'phone': '+12123661182',
#    'display_phone': '(212) 366-1182',
#    'distance': 1743.7585301414076},
#   {'id': 'WG639VkTjmK5dzydd1BBJA',
#    'alias': 'rubirosa-new-york-2',
#    'name': 'Rubirosa',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/LuSzR8cpVQRofXOT_bMi1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/rubirosa-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 2111,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.72275, 'longitude': -73.99622},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '235 Mulberry St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['235 Mulberry St', 'New York, NY 10012']},
#    'phone': '+12129650500',
#    'display_phone': '(212) 965-0500',
#    'distance': 1254.8987502464195},
#   {'id': '0UdC0VYX6aAvLiOcpR4MVQ',
#    'alias': 'joes-pizza-new-york-7',
#    'name': "Joe's Pizza",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/9E2Um0ddicKyoWS-RGIXyg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/joes-pizza-new-york-7?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 843,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73331, 'longitude': -73.98763},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '150 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['150 E 14th St', 'New York, NY 10003']},
#    'phone': '+12123889474',
#    'display_phone': '(212) 388-9474',
#    'distance': 865.5899869147826},
#   {'id': 'Ajvcvk6tvlKbRF8Zkf0M5Q',
#    'alias': 'marinara-pizza-new-york-8',
#    'name': 'Marinara Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/14ta7LbwwXc7Jdh2LRuTBg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/marinara-pizza-new-york-8?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 19,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.74241, 'longitude': -73.98452},
#    'transactions': ['pickup', 'delivery'],
#    'location': {'address1': '379 Park Ave S',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'zip_code': '10016',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['379 Park Ave S', 'New York, NY 10016']},
#    'phone': '+16466495282',
#    'display_phone': '(646) 649-5282',
#    'distance': 1770.736647438582},
#   {'id': 'eVk4F9ixl89zyUHJ1G2Aiw',
#    'alias': 'luzzos-la-pizza-napoletana-new-york-10',
#    'name': 'Luzzos La Pizza Napoletana',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/siQq0MnFSCXmAd8rg28EwQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/luzzos-la-pizza-napoletana-new-york-10?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 1032,
#    'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.730616, 'longitude': -73.9834846},
#    'transactions': ['pickup', 'restaurant_reservation', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '211 1st Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['211 1st Ave', 'New York, NY 10003']},
#    'phone': '+12124737447',
#    'display_phone': '(212) 473-7447',
#    'distance': 462.36038428059834},
#   {'id': 'LF1QAuvpfX7KGQlg2zMg6Q',
#    'alias': 'johns-of-bleecker-street-new-york-2',
#    'name': "John's of Bleecker Street",
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/ey_5ReYpouWm4SlY2DsaVQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/johns-of-bleecker-street-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 1946,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.73158, 'longitude': -74.00332},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '278 Bleecker St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['278 Bleecker St', 'New York, NY 10014']},
#    'phone': '+12122431680',
#    'display_phone': '(212) 243-1680',
#    'distance': 1876.8363324785919},
#   {'id': 'oJ_XSPZFpvIt6rvheSQl7A',
#    'alias': 'bleecker-street-pizza-new-york',
#    'name': 'Bleecker Street Pizza',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/Kyi2tP43S_a6s-zXD38NUQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bleecker-street-pizza-new-york?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 2276,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7320627016512,
#     'longitude': -74.0036552270137},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '69 7th Ave S',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10014',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['69 7th Ave S', 'New York, NY 10014']},
#    'phone': '+12129244466',
#    'display_phone': '(212) 924-4466',
#    'distance': 1891.7926117225477},
#   {'id': 'MeQU-nGaQvX12VXYOyzavQ',
#    'alias': 'gruppo-new-york-4',
#    'name': 'Gruppo',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/mCZI4W3FgjwMS-G054lxZw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/gruppo-new-york-4?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 249,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'beerbar', 'title': 'Beer Bar'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.72474, 'longitude': -73.98161},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$$',
#    'location': {'address1': '98 Ave B',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['98 Ave B', 'New York, NY 10009']},
#    'phone': '+12129952100',
#    'display_phone': '(212) 995-2100',
#    'distance': 209.4694403367121},
#   {'id': 'orvnuNWLuoE3-iEx4Aj8eA',
#    'alias': 'bakers-pizza-new-york',
#    'name': "Baker's Pizza",
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/3TbUAZcHe7PQ278pONEU0w/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/bakers-pizza-new-york?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 199,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7294399, 'longitude': -73.98125},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '201 Avenue A',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10009',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['201 Avenue A', 'New York, NY 10009']},
#    'phone': '+12127777477',
#    'display_phone': '(212) 777-7477',
#    'distance': 330.347070163572},
#   {'id': 'vfYhEpp0x-DrNjC6GSJjPQ',
#    'alias': 'artichoke-basilles-pizza-new-york-2',
#    'name': "Artichoke Basille's Pizza",
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/53JHO_-CRJ_e43JJIuN_Og/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/artichoke-basilles-pizza-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 3910,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7321124557704,
#     'longitude': -73.9839056828882},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '321 E 14th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10003',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['321 E 14th St', 'New York, NY 10003']},
#    'phone': '+12122282004',
#    'display_phone': '(212) 228-2004',
#    'distance': 632.4507704855928},
#   {'id': 'BgGz5IdV53bGb4o7opR5zg',
#    'alias': 'arturos-new-york',
#    'name': "Arturo's",
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Eh-8a3MUYlpatlpHs3mHJg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/arturos-new-york?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 665,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#     {'alias': 'italian', 'title': 'Italian'}],
#    'rating': 4.0,
#    'coordinates': {'latitude': 40.7273563342024,
#     'longitude': -74.0004944801331},
#    'transactions': ['restaurant_reservation'],
#    'price': '$$',
#    'location': {'address1': '106 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10012',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['106 W Houston St', 'New York, NY 10012']},
#    'phone': '+12126773820',
#    'display_phone': '(212) 677-3820',
#    'distance': 1544.8068092117087},
#   {'id': 'zmIrZgWhRdyRMrnEs9D3KA',
#    'alias': 'la-margarita-pizzeria-new-york',
#    'name': 'La Margarita Pizzeria',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/7NH6z9iOZETlq8AKFwkcyQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/la-margarita-pizzeria-new-york?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#    'review_count': 284,
#    'categories': [{'alias': 'pizza', 'title': 'Pizza'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 40.7215392420787,
#     'longitude': -73.9876275438289},
#    'transactions': ['pickup', 'delivery'],
#    'price': '$',
#    'location': {'address1': '168 Ludlow St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'zip_code': '10002',
#     'country': 'US',
#     'state': 'NY',
#     'display_address': ['168 Ludlow St', 'New York, NY 10002']},
#    'phone': '+19172614983',
#    'display_phone': '(917) 261-4983',
#    'distance': 723.4903673179167}],
#  'total': 5200,
#  'region': {'center': {'longitude': -73.98219108581543,
#    'latitude': 40.726575080877375}}}

# %% [markdown]
# Now let's go a bit further and start to preview what's stored in each of the values for these keys.

# %%
data = response.json()

# %%
for key in data.keys():
    print(key)
    value = response.json()[key] #Use standard dictionary formatting
    print(type(value)) #What type is it?
    print('\n\n') #Seperate out data
# Out:
# businesses
# <class 'list'>
#
#
#
# total
# <class 'int'>
#
#
#
# region
# <class 'dict'>

# %% [markdown]
# Let's make sure our data is as expected by looking at a couple of different business by taking a slice of the data.

# %%
data['businesses'][0]
# Out:
# {'id': 'zj8Lq1T8KIC5zwFief15jg',
#  'alias': 'prince-street-pizza-new-york-2',
#  'name': 'Prince Street Pizza',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ZAukOyv530w4KjOHC5YY1w/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/prince-street-pizza-new-york-2?adjust_creative=SrP-vVinyIiYU2-NOuqnOA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=SrP-vVinyIiYU2-NOuqnOA',
#  'review_count': 3271,
#  'categories': [{'alias': 'pizza', 'title': 'Pizza'},
#   {'alias': 'italian', 'title': 'Italian'}],
#  'rating': 4.5,
#  'coordinates': {'latitude': 40.7229087705545, 'longitude': -73.9944863319397},
#  'transactions': ['pickup', 'delivery'],
#  'price': '$',
#  'location': {'address1': '27 Prince St',
#   'address2': None,
#   'address3': '',
#   'city': 'New York',
#   'zip_code': '10012',
#   'country': 'US',
#   'state': 'NY',
#   'display_address': ['27 Prince St', 'New York, NY 10012']},
#  'phone': '+12129664100',
#  'display_phone': '(212) 966-4100',
#  'distance': 1113.4297052662043}

# %% [markdown]
# There are a lot of key-value pairs for each business. Many of which we do not care about. Let's create a simple parser of this data that will return a tuple with the name, display_address, and one other data point of your choice.

# %%
#Select one to work on
business = data['businesses'][0]

# %%
#Create a tuple that contains only the information that we want
#the join is used because that result comes back as a list and we want to convert into a string
biz_tuple = (business['name'], ' '.join(business['location']['display_address']), business['rating'])

# %%
#Check your tuple
biz_tuple
# Out:
# ('Prince Street Pizza', '27 Prince St New York, NY 10012', 4.5)

# %% [markdown]
# Now that we know how to do this for one business. Let create a function that recieves the list of businesses and returns a list of tuples with the important information.

# %%
def parse_data(data_list):
    # create a container to hold our parsed data
    parse_data = []  
    
    # loop through our business and parse each individual business
    for business in data_list:
        biz_tuple = (business['name'], ' '.join(business['location']['display_address']), business['rating'])
    # in the loop, add each individual parsed parsed business to our data container
        parse_data.append(biz_tuple)
    # return the container with all of the parsed results     
    return parse_data

# %%
parse_data(data['businesses'])
# Out:
# [('Prince Street Pizza', '27 Prince St New York, NY 10012', 4.5),
#  ("Lombardi's Pizza", '32 Spring St New York, NY 10012', 4.0),
#  ("Juliana's Pizza", '19 Old Fulton St Brooklyn, NY 11201', 4.5),
#  ("Vito's Slices and Ices", '464 9th Ave New York, NY 10018', 5.0),
#  ("Rizzo's Fine Pizza", '17 Clinton St New York, NY 10002', 4.5),
#  ("L'industrie Pizzeria", '254 S 2nd St Brooklyn, NY 11211', 5.0),
#  ('Lions & Tigers & Squares Detroit Pizza',
#   '160 2nd Ave New York, NY 10003',
#   4.0),
#  ('Village Square Pizza', '147 Ave A New York, NY 10009', 4.5),
#  ("Joe's Pizza", '7 Carmine St New York, NY 10014', 4.0),
#  ('Rubirosa', '235 Mulberry St New York, NY 10012', 4.5),
#  ("Joe's Pizza", '150 E 14th St New York, NY 10003', 4.0),
#  ('Marinara Pizza', '379 Park Ave S New York, NY 10016', 4.5),
#  ('Luzzos La Pizza Napoletana', '211 1st Ave New York, NY 10003', 4.0),
#  ("John's of Bleecker Street", '278 Bleecker St New York, NY 10014', 4.0),
#  ('Bleecker Street Pizza', '69 7th Ave S New York, NY 10014', 4.0),
#  ('Gruppo', '98 Ave B New York, NY 10009', 4.0),
#  ("Baker's Pizza", '201 Avenue A New York, NY 10009', 4.5),
#  ("Artichoke Basille's Pizza", '321 E 14th St New York, NY 10003', 4.0),
#  ("Arturo's", '106 W Houston St New York, NY 10012', 4.0),
#  ('La Margarita Pizzeria', '168 Ludlow St New York, NY 10002', 4.5)]
